# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# UI latency horizontal
data1 = {
    "metric": "DEMAND",
    "results": [
        [{"first": 1, "second": 1}, True],
        [{"first": 3, "second": 1}, True],
        [{"first": 5, "second": 1}, False],
        [{"first": 5, "second": 2}, True],
        [{"first": 7, "second": 2}, True],
        [{"first": 9, "second": 2}, True],
        [{"first": 11, "second": 2}, False],
        [{"first": 11, "second": 3}, False],
        [{"first": 11, "second": 4}, False]
    ],
    "optInstances": {
        "1": 1,
        "3": 1,
        "5": 2,
        "7": 2,
        "9": 2,
        "11": 2147483647
    }
}



# UI Latency vertical
data2 = {
    "metric": "DEMAND",
    "results": [
        [{"first": 1, "second": 500}, True],
        [{"first": 3, "second": 500}, True],
        [{"first": 5, "second": 500}, False],
        [{"first": 5, "second": 1000}, True],
        [{"first": 7, "second": 1000}, True],
        [{"first": 9, "second": 1000}, True],
        [{"first": 11, "second": 1000}, True],
        [{"first": 13, "second": 1000}, False],
        [{"first": 13, "second": 1500}, False],
        [{"first": 13, "second": 2000}, False]
    ],
    "optInstances": {
        "1": 500,
        "3": 500,
        "5": 1000,
        "7": 1000,
        "9": 1000,
        "11": 1000,
        "13": 2147483647
    }
}
#  latency horizontal
data3 = {
    "metric": "DEMAND",
    "results": [
        [{"first": 1, "second": 1}, True],
        [{"first": 3, "second": 1}, True],
        [{"first": 5, "second": 1}, True],
        [{"first": 7, "second": 1}, False],
        [{"first": 7, "second": 2}, True],
        [{"first": 9, "second": 2}, True],
        [{"first": 11, "second": 2}, True],
        [{"first": 13, "second": 2}, True],
        [{"first": 15, "second": 2}, True],
        [{"first": 17, "second": 2}, False],
        [{"first": 17, "second": 3}, True],
        [{"first": 19, "second": 3}, False],
        [{"first": 19, "second": 4}, True],
        [{"first": 21, "second": 4}, False],
        

    ],
    "optInstances": {
        "1": 1,
        "3": 1,
        "5": 1,
        "7": 2,
        "9": 2,
        "11": 2,
        "13": 2,
        "15": 2,
        "17": 3,
        "19": 4,
        "21": 2147483647
    }
}
#  Latency vertical 
data4 = {
    "metric": "DEMAND",
    "results": [
        [{"first": 1, "second": 500}, True],
        [{"first": 3, "second": 500}, True],
        [{"first": 5, "second": 500}, True],
        [{"first": 7, "second": 500}, False],
        [{"first": 7, "second": 1000}, True],
        [{"first": 9, "second": 1000}, True],
        [{"first": 11, "second": 1000}, True],
        [{"first": 13, "second": 1000}, False],
        [{"first": 13, "second": 1500}, False],
        [{"first": 13, "second": 2000}, True],
        [{"first": 15, "second": 2000}, True],
        [{"first": 17, "second": 2000}, True],
        [{"first": 19, "second": 2000}, True],
        [{"first": 21, "second": 2000}, True],
        [{"first": 23, "second": 2000}, True],
        [{"first": 25, "second": 2000}, False],
    ],
    "optInstances": {
        "1": 500,
        "3": 500,
        "5": 500,
        "7": 1000,
        "9": 1000,
        "11": 1000,
        "13": 2000,
        "15": 2000,
        "17": 2000,
        "19": 2000,
        "21": 2000,
        "23": 2000,
        "25": 2147483647
    }
}

#  Throughput horizontal
data5 = {
    "metric": "DEMAND",
    "results": [
        [{"first": 1, "second": 1}, True],
        [{"first": 3, "second": 1}, True],
        [{"first": 5, "second": 1}, True],
        [{"first": 7, "second": 1}, False],
        [{"first": 7, "second": 2}, True],
        [{"first": 9, "second": 2}, True],
        [{"first": 11, "second": 2}, True],
        [{"first": 13, "second": 2}, False],
        [{"first": 13, "second": 3}, True],
        [{"first": 15, "second": 3}, True],
        [{"first": 17, "second": 3}, True],
        [{"first": 19, "second": 3}, False],
        [{"first": 19, "second": 4}, True],
        [{"first": 21, "second": 4}, False],
    ],
    "optInstances": {
        "1": 1,
        "3": 1,
        "5": 1,
        "7": 2,
        "9": 2,
        "11": 2,
        "13": 3,
        "15": 3,
        "17": 3,
        "19": 4,
        "21": 2147483647
    }
}

#  Throughput vertical 
data6 = {
    "metric": "DEMAND",
    "results": [
        [{"first": 1, "second": 500}, True],
        [{"first": 3, "second": 500}, True],
        [{"first": 5, "second": 500}, True],
        [{"first": 7, "second": 500}, False],
        [{"first": 7, "second": 1000}, True],
        [{"first": 9, "second": 1000}, True],
        [{"first": 11, "second": 1000}, True],
        [{"first": 13, "second": 1000}, False],
        [{"first": 13, "second": 1500}, True],
        [{"first": 15, "second": 1500}, True],
        [{"first": 17, "second": 1500}, True],
        [{"first": 19, "second": 1500}, True],
        [{"first": 21, "second": 1500}, False],
        [{"first": 21, "second": 2000}, True],
        [{"first": 23, "second": 2000}, True],
        [{"first": 25, "second": 2000}, False],
    ],
    "optInstances": {
        "1": 500,
        "3": 500,
        "5": 500,
        "7": 1000,
        "9": 1000,
        "11": 1000,
        "13": 1500,
        "15": 1500,
        "17": 1500,
        "19": 1500,
        "21": 2000,
        "23": 2000,
        "25": 2147483647
    }
}

def parse_json(data):
    df = pd.DataFrame({
        'Resource Demand': [item[0]['first'] for item in data['results']],
        'Resource Capacity': [item[0]['second'] for item in data['results']],
        'Can Handle': [item[1] for item in data['results']],
    })
    return df

df1 = parse_json(data1)
df2 = parse_json(data2)
df3 = parse_json(data3)
df4 = parse_json(data4)
df5 = parse_json(data5)
df6 = parse_json(data6)

# %%
def plot_line_chart_horizontal(df, title, x_label, y_label):
    df_sorted = df.sort_values(by='Resource Demand')
    
    plt.figure(figsize=(10, 6))

    plt.plot(df_sorted['Resource Demand'], df_sorted['Resource Capacity'], marker='s', color='blue', label='Resource Capacity')

    can_handle_df = df_sorted[df_sorted['Can Handle']]
    plt.scatter(can_handle_df['Resource Demand'], can_handle_df['Resource Capacity'], color='green', edgecolor='k', label='Can Handle', zorder=5)

    cannot_handle_df = df_sorted[~df_sorted['Can Handle']]
    plt.scatter(cannot_handle_df['Resource Demand'], cannot_handle_df['Resource Capacity'], color='red', edgecolor='k', label='Cannot Handle', zorder=5)

    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.xticks(range(0, int(df_sorted['Resource Demand'].max()) + 1))
    plt.yticks(range(0, int(df_sorted['Resource Capacity'].max()) + 1)) 
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
def plot_line_chart_vertical(df, title, x_label, y_label):
    # Sort the DataFrame by 'Resource Demand'
    df_sorted = df.sort_values(by='Resource Demand')
    
    # Plotting setup
    plt.figure(figsize=(10, 6))

    # Plot the line for 'Resource Capacity'
    plt.plot(df_sorted['Resource Demand'], df_sorted['Resource Capacity'], marker='s', linestyle='-', color='blue', label='Resource Capacity')

    # Scatter plot for 'Can Handle' = True
    can_handle_df = df_sorted[df_sorted['Can Handle']]
    plt.scatter(can_handle_df['Resource Demand'], can_handle_df['Resource Capacity'], color='green', edgecolor='k', label='Can Handle', zorder=5)

    # Scatter plot for 'Can Handle' = False
    cannot_handle_df = df_sorted[~df_sorted['Can Handle']]
    plt.scatter(cannot_handle_df['Resource Demand'], cannot_handle_df['Resource Capacity'], color='red', edgecolor='k', label='Cannot Handle', zorder=5)


    # Graph labels and legend
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.xticks(range(int(df_sorted['Resource Demand'].min()), int(df_sorted['Resource Demand'].max()) + 1))
    plt.yticks(range(0, int(df_sorted['Resource Capacity'].max()) + 1, max(1, int(df_sorted['Resource Capacity'].max()/10))))
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
plot_title = 'Horizontal Scaling Assessment with UI Latency SLO (95th Percentile <= 200ms) with Load Balancer'
plot_line_chart_horizontal(df1, plot_title, 'Number of Concurrent Users', 'Number of Instances')

# %%
vertical_plot_title = 'Vertical Scaling Assessment with UI Latency SLO (95th Percentile <= 200ms) with Load Balancer'
plot_line_chart_vertical(df2, vertical_plot_title, 'Number of Concurrent Users', 'CPU Allocation (millicores) per pod')

# %%
plot_title = 'Horizontal Scaling Assessment with Latency SLO (95th Percentile <= 200ms) with Load Balancer'
plot_line_chart_horizontal(df3, plot_title, 'Number of Concurrent Users', 'Number of Instances')

# %%
vertical_plot_title = 'Vertical Scaling Assessment with Latency SLO (95th Percentile <= 200ms) with Load Balancer'
plot_line_chart_vertical(df4, vertical_plot_title, 'Number of Concurrent Users', 'CPU Allocation (millicores) per pod')

# %%
plot_title = 'Horizontal Scaling Assesment for Throughput: Achieving >= 80% of Target Rate with Load Balancer'
plot_line_chart_horizontal(df5, plot_title, 'Number of Concurrent Users', 'Number of Instances')

# %%
vertical_plot_title = 'Horizontal Scaling Assesment for Throughput: Achieving >= 80% of Target Rate with Load Balancer'
plot_line_chart_vertical(df6, vertical_plot_title, 'Number of Concurrent Users', 'CPU Allocation (millicores) per pod')
